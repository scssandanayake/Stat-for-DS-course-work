# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# %%
df = pd.read_csv("/content/SriLanka_Weather_Dataset.csv")

# %%
selected_columns = df[['rain_sum', 'temperature_2m_mean', 'city']]

# %%
ra_df = selected_columns[selected_columns['city'] == 'Ratnapura']

# %%
ga_df = selected_columns[selected_columns['city'] == 'Galle']

# %%
ra_df_rain = ra_df['rain_sum'].to_frame()
ga_df_rain = ga_df['rain_sum'].to_frame()

# %%
ra_df_rain
# Out:
#        rain_sum
# 24580       0.1
# 24581       0.9
# 24582       2.5
# 24583       0.2
# 24584       0.0
# ...         ...
# 29491      13.4
# 29492       8.4
# 29493       4.2
# 29494       6.6
# 29495       4.4
#
# [4916 rows x 1 columns]

# %%
ga_df_rain
# Out:
#        rain_sum
# 54076       0.4
# 54077       1.4
# 54078       3.3
# 54079       1.2
# 54080       0.0
# ...         ...
# 58987       8.0
# 58988       5.6
# 58989       2.2
# 58990       3.0
# 58991       6.2
#
# [4916 rows x 1 columns]

# %%
ra_df_rain.reset_index(inplace = True)
ga_df_rain.reset_index(inplace = True)

df_new2 = pd.DataFrame()
df_new2['rathnapura_rain'] = ra_df_rain['rain_sum']
df_new2['galle_rain'] = ga_df_rain['rain_sum']
print(df_new2)
# Out:
#       rathnapura_rain  galle_rain
# 0                 0.1         0.4
# 1                 0.9         1.4
# 2                 2.5         3.3
# 3                 0.2         1.2
# 4                 0.0         0.0
# ...               ...         ...
# 4911             13.4         8.0
# 4912              8.4         5.6
# 4913              4.2         2.2
# 4914              6.6         3.0
# 4915              4.4         6.2
#
# [4916 rows x 2 columns]

# %%
df_new2.to_csv("hypothesisrain.csv")

# %%
selected_columns.head()
# Out:
#    rain_sum  temperature_2m_mean     city
# 0       0.0                 26.1  Colombo
# 1       0.1                 26.2  Colombo
# 2       0.6                 26.0  Colombo
# 3       0.0                 25.3  Colombo
# 4       0.0                 24.5  Colombo

# %%
selected_rows = selected_columns[selected_columns['city'] == 'Ratnapura']

# %%
selected_rows.shape
# Out:
# (4916, 3)

# %%
selected_rows.head()
# Out:
#        rain_sum  temperature_2m_mean       city
# 24580       0.1                 25.4  Ratnapura
# 24581       0.9                 25.4  Ratnapura
# 24582       2.5                 24.9  Ratnapura
# 24583       0.2                 24.2  Ratnapura
# 24584       0.0                 23.6  Ratnapura

# %%
selected_rows.to_csv("hypothesisrathnetemprain.csv")

# %%
plt.hist(selected_rows['rain_sum'], bins=10, color='skyblue', edgecolor='black', alpha=0.7)

mean = selected_rows['rain_sum'].mean()
std_dev = selected_rows['rain_sum'].std()

x = np.linspace(selected_rows['rain_sum'].min(), selected_rows['rain_sum'].max(), 100)

plt.xlabel('Values')
plt.ylabel('Counts')
plt.title('Histogram for Ratnapura rain_sum')

plt.show()

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
plt.hist(selected_rows['temperature_2m_mean'], bins=10, color='skyblue', edgecolor='black', alpha=0.7)

mean = selected_rows['temperature_2m_mean'].mean()
std_dev = selected_rows['temperature_2m_mean'].std()

x = np.linspace(selected_rows['temperature_2m_mean'].min(), selected_rows['temperature_2m_mean'].max(), 100)

plt.xlabel('Values')
plt.ylabel('Counts')
plt.title('Histogram for Ratnapura temperature_2m_mean')

plt.show()
